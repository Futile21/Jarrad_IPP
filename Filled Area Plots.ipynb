# %%
import dash
import plotly.graph_objs as go
# import dash_bootstrap_components as dbc
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output, State
import pandas as pd
import numpy as np
# import dash_daq as daq
import io
import base64

# %%
IRP2019_P = pd.read_excel('2019-IRP.xlsx', sheet_name="IRP1_P").round(1)
IRP2019_E = pd.read_excel('2019-IRP.xlsx', sheet_name="IRP1_E").round(1)

CSIR_LC_2019_P = pd.read_excel('2019-CSIR_LC.xlsx', sheet_name="IRP1_P").round(1)
CSIR_LC_2019_E = pd.read_excel('2019-CSIR_LC.xlsx', sheet_name="IRP1_E").round(1)

IRP2019_P2 = (IRP2019_P * 0.8).round(1)
IRP2019_E2 = (IRP2019_E * 0.8).round(1)

CSIR_LC_2019_P2 = (CSIR_LC_2019_P * 0.8).round(1)
CSIR_LC_2019_E2 = (CSIR_LC_2019_E * 0.8).round(1)

powerlist = list(CSIR_LC_2019_E.columns)
print(powerlist)
removelist = [powerlist[0], powerlist[11], powerlist[13]]
removelist
for i in removelist:
    print(f'remove {i}')
    powerlist.remove(i)
# Out:
# ['Year', 'COA', 'NUC', 'GAS', 'PEA', 'HYD', 'WIN', 'CSP', 'SPV', 'DPV', 'BIO', 'DSR', 'PST', 'STO']
# remove Year
# remove DSR
# remove STO

# %%
colours = ['#8c664a', '#ff270f', '#969696', '#e8d2ca', '#2760a6', '#9db1cf', '#eea632', '#ffed11', '#d7c700', '#007770'
                    , '#0a346f', ]

# %%
traces = []
fig = go.Figure()

for i, power in enumerate(powerlist):
    traces.append(
        fig.add_trace(go.Scatter(x=IRP2019_P['Year'],
                   y=IRP2019_P[power],
                   name=power,
                   legendgroup=power,
                   marker=dict(color=colours[i]),
                   stackgroup='one',
                   )
    ))

for i, power in enumerate(powerlist):
    traces.append(
        fig.add_trace(go.Scatter(x=CSIR_LC_2019_P['Year'],
                   y=CSIR_LC_2019_P[power],
                   name=power,
                   legendgroup=power,
                   marker=dict(color=colours[i]),
                   stackgroup='Two',
                   mode='lines',
                   line={'dash': 'dash'},
                   )
    ))


fig.show()
# Out:
# <div>
#
#
#             <div id="872a9005-4d47-42ac-b77b-6b94576b37ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("872a9005-4d47-42ac-b77b-6b94576b37ad")) {
#                     Plotly.newPlot(
#                         '872a9005-4d47-42ac-b77b-6b94576b37ad',
#                         [{"legendgroup": "COA", "marker": {"color": "#8c664a"}, "name": "COA", "stackgroup": "one", "type": "scatter", "x": [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050], "y": [37625.0, 38671.0, 37457.0, 38038.0, 38014.0, 38964.0, 38758.0, 38438.0, 37112.0, 37326.0, 37326.0, 35801.0, 32941.0, 31791.0, 30066.0, 28916.0, 28341.0, 28092.1, 27565.7, 27047.3, 26931.0, 26996.9, 26381.9, 25605.2, 26164.4, 26241.8, 26430.8, 26430.8, 27351.5, 28150.9, 28337.5, 27670.5, 27003.5]}, {"legendgroup": "NUC", "marker": {"color": "#ff270f"}, "name": "NUC", "stackgroup": "one", "type": "scatter", "x": [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050], "y": [1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 1860, 930, 0, 0, 0, 0]}, {"legendgroup": "GAS", "marker": {"color": "#969696"}, "name": "GAS", "stackgroup": "one", "type": "scatter", "x": [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050], "y": [424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 424.6, 745.1, 745.1, 894.4, 1722.2, 1722.2, 1722.2, 2499.6, 2712.0, 2712.0, 2712.0, 2712.0, 4328.9, 4328.9, 6319.1, 6319.1, 6319.1]}, {"legendgroup": "PEA", "marker": {"color": "#e8d2ca"}, "name": "PEA", "stackgroup": "one", "type": "scatter", "x": [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050], "y": [3405.0, 3405.0, 3405.0, 3405.0, 3405.0, 3405.0, 4461.0, 4461.0, 4119.0, 6231.0, 6231.0, 6231.0, 6231.0, 6660.4, 9275.7, 9887.0, 9931.1, 10237.8, 10237.8, 12027.9, 12469.5, 11146.5, 11146.5, 11146.5, 12756.8, 13621.1, 14013.0, 14013.0, 13292.9, 13292.9, 13294.1, 13294.1, 13294.1]}, {"legendgroup": "HYD", "marker": {"color": "#2760a6"}, "name": "HYD", "stackgroup": "one", "type": "scatter", "x": [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050], "y": [2192, 2192, 2192, 2192, 2192, 2192, 2192, 2192, 2192, 2192, 2192, 2192, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692, 4692]}, {"legendgroup": "WIN", "marker": {"color": "#9db1cf"}, "name": "WIN", "stackgroup": "one", "type": "scatter", "x": [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050], "y": [2086, 2086, 2226, 2762, 4362, 5962, 7562, 9162, 10762, 12362, 13962, 15562, 17162, 18762, 20362, 21962, 22526, 23076, 24676, 26276, 27876, 29476, 30940, 32000, 32000, 32000, 32000, 32000, 32000, 32000, 32000, 32000, 32000]}, {"legendgroup": "CSP", "marker": {"color": "#eea632"}, "name": "CSP", "stackgroup": "one", "type": "scatter", "x": [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050], "y": [400.0, 500.0, 500.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 600.0, 500.0, 400.0, 200.0, 591.9, 1744.4, 2001.1]}, {"legendgroup": "SPV", "marker": {"color": "#ffed11"}, ...

# %%
len(colours)
# Out:
# 11

# %%
len(powerlist)
# Out:
# 14
